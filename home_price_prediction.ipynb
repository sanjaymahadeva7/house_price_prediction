# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("housing.csv")

# %%
dataset.shape
# Out:
# (20640, 10)

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataset.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
dataset.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
# Assuming 'data' is your DataFrame containing the dataset
unique_values = dataset['ocean_proximity'].unique()
print(unique_values)
# Out:
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']

# %%
print(dataset.isnull().sum())
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
dataset['total_bedrooms'].fillna(dataset['total_bedrooms'].median(), inplace=True)

# Check for any remaining missing values
print(dataset.isnull().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
from FeatureScore import FeatureScoreCalculator

# %%
# Histograms
dataset.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='median_income', y='median_house_value', data=dataset)
plt.title('Median Income vs. Median House Value')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.show()

# %%
# Geospatial Visualization
plt.figure(figsize=(10, 8))
sns.scatterplot(x='longitude', y='latitude', hue='median_house_value', data=dataset, palette='viridis', alpha=0.6)
plt.title('Geospatial Visualization of Median House Value')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Median House Value', loc='lower right')
plt.show()

# %%
# Bar Chart
plt.figure(figsize=(8, 6))
sns.countplot(x='ocean_proximity', data=dataset)
plt.title('Count of Houses by Ocean Proximity')
plt.xlabel('Ocean Proximity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
target="median_house_value"
calculator = FeatureScoreCalculator(dataset, target)
calculator.display_scores()
# Out:
# Feature 1: median_income - Correlation Score = 100.00
# Feature 2: latitude - Correlation Score = 20.95
# Feature 3: total_rooms - Correlation Score = 19.50
# Feature 4: housing_median_age - Correlation Score = 15.35
# Feature 5: ocean_proximity - Correlation Score = 11.88
# Feature 6: households - Correlation Score = 9.57
# Feature 7: total_bedrooms - Correlation Score = 7.19
# Feature 8: longitude - Correlation Score = 6.68
# Feature 9: population - Correlation Score = 3.58

# %%
X = dataset.drop('median_house_value', axis=1)
y = dataset['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
categorical_features = ['ocean_proximity']
numerical_features = X.columns.drop(categorical_features)

# Create column transformer with OneHotEncoder for categorical features and StandardScaler for numerical features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("\nTraining data size:", X_train.shape)
print("Testing data size:", X_test.shape)
# Out:
# Training data size: (16512, 9)
# Testing data size: (4128, 9)

# %%
# Apply preprocessing to training and testing data
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
print(X_train[:5])
# Out:
# [[ 1.00389865 -0.8400624  -1.79507596 -0.97773624 -1.0957179  -1.04760128
#   -1.1356496   0.19001247  0.          1.          0.          0.
#    0.        ]
#  [-1.43477229  0.98536392  1.85553889 -0.11850059 -0.10622101  0.05210918
#   -0.13688171  0.26931072  0.          0.          0.          1.
#    0.        ]
#  [ 0.77948108 -0.8400624  -0.20785212 -0.42167953 -0.36073103 -0.35295521
#   -0.34343319  0.02989505  1.          0.          0.          0.
#    0.        ]
#  [ 0.64981759 -0.75581196  0.74448219 -0.88856596 -0.78174293 -0.59179448
#   -0.76699444 -1.26447048  1.          0.          0.          0.
#    0.        ]
#  [ 0.59994702 -0.72304789  1.85553889 -0.12215886  0.15304621 -0.25409501
#    0.20039854 -0.36701574  1.          0.          0.          0.
#    0.        ]]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

# Show your regression model's score
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
print(f'\nTraining score: {train_score}')
print(f'Testing score: {test_score}')
# Out:
# Training score: 0.647164612389798
# Testing score: 0.6380862497737064

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions on the testing data
y_pred = model.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error: 49707.42799359941
# Mean Squared Error: 4719192088.227013
# R-squared: 0.6380862497737064

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define the neural network architecture
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),  # Optional: Dropout layer to reduce overfitting
    Dense(64, activation='relu'),
    Dense(1)  # Output layer with 1 neuron for regression task
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Print a summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,113 (39.50 KB)
#  Trainable params: 10,113 (39.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 55984857088.0000 - mean_absolute_error: 206113.0469 - val_loss: 50824900608.0000 - val_mean_absolute_error: 195305.0625
# Epoch 2/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 937us/step - loss: 46147399680.0000 - mean_absolute_error: 184277.0156 - val_loss: 29308884992.0000 - val_mean_absolute_error: 136826.8750
# Epoch 3/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step - loss: 24209784832.0000 - mean_absolute_error: 120166.3359 - val_loss: 12474330112.0000 - val_mean_absolute_error: 81329.8984
# Epoch 4/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10960559104.0000 - mean_absolute_error: 76072.4531 - val_loss: 8614867968.0000 - val_mean_absolute_error: 67115.3125
# Epoch 5/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8140208128.0000 - mean_absolute_error: 65216.1875 - val_loss: 7145150464.0000 - val_mean_absolute_error: 60107.5742
# Epoch 6/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7061710848.0000 - mean_absolute_error: 59578.5508 - val_loss: 6270155264.0000 - val_mean_absolute_error: 55680.6133
# Epoch 7/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6108576256.0000 - mean_absolute_error: 55371.2344 - val_loss: 5681469440.0000 - val_mean_absolute_error: 53284.0234
# Epoch 8/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5760543232.0000 - mean_absolute_error: 54018.8438 - val_loss: 5315527168.0000 - val_mean_absolute_error: 51883.9961
# Epoch 9/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5406855168.0000 - mean_absolute_error: 52675.8750 - val_loss: 5087886336.0000 - val_mean_absolute_error: 50916.3320
# Epoch 10/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5221117952.0000 - mean_absolute_error: 52064.0000 - val_loss: 4950799872.0000 - val_mean_absolute_error: 50342.0664
# Epoch 11/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4901932544.0000 - mean_absolute_error: 50478.2578 - val_loss: 4865137664.0000 - val_mean_absolute_error: 49968.2656
# Epoch 12/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4874722816.0000 - mean_absolute_error: 50641.2930 - val_loss: 4808956416.0000 - val_mean_absolute_error: 49818.2969
# Epoch 13/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4742027776.0000 - mean_absolute_error: 50232.2500 - val_loss: 4769410560.0000 - val_mean_absolute_error: 49700.3281
# Epoch 14/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4813342208.0000 - mean_absolute_error: 50279.9180 - val_loss: 4735603200.0000 - val_mean_absolute_error: 49292.1406
# Epoch 15/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4754550784.0000 - mean_absolute_error: 49828.2812 - val_loss: 4710206464.0000 - val_mean_absolute_error: 49017.0664
# Epoch 16/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4761104384.0000 - mean_absolute_error: 49328.5156 - val_loss: 4687964672.0000 - val_mean_absolute_error: 49066.6289
# Epoch 17/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4662339584.0000 - mean_absolute_error: 49353.9219 - val_loss: 4669235200.0000 - val_mean_absolute_error: 48964.4727
# Epoch 18/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4886841856.0000 - mean_absolute_error: 50400.3281 - val_loss: 4652731392.0000 - val_mean_absolute_error: 48809.2148
# Epoch 19/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4832748544.0000 - mean_absolute_error: 49917.7070 - val_loss: 4637884416.0000 - val_mean_absolute_error: 48830.6094
# Epoch 20/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4765084160.0000 - mean_absolute_error: 49876.8047 - val_loss: 4628378112.0000 - val_mean_absolute_error: 49002.6875
# Epoch 21/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4730094592.0000 - mean_absolute_error: 49415.7773 - val_loss: 4613774848.0000 - val_mean_absolute_error: 48907.1680
# Epoch 22/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4693476864.0000 - mean_absolute_error: 49710.8750 - val_loss: 4600283136.0000 - val_mean_absolute_error: 48680.0859
# Epoch 23/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 951us/step - loss: 4629073408.0000 - mean_absolute_error: 49046.5039 - val_loss: 4594653696.0000 - val_mean_absolute_error: 48597.1367
# Epoch 24/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4700883456.0000 - mean_absolute_error: 49025.6250 - val_loss: 4580694016.0000 - val_mean_absolute_error: 48604.2070
# Epoch 25/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4574096384.0000 - mean_absolute_error: 48969.3594 - val_loss: 4569178112.0000 - val_mean_absolute_error: 48354.4414
# Epoch 26/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 4721925632.0000 - mean_absolute_error: 49276.2617 - val_loss: 4564177920.0000 - val_mean_absolute_error: 48565.3086
# Epoch 27/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4692652032.0000 - mean_absolute_error: 49477.7578 - val_loss: 4553141248.0000 - val_mean_absolute_error: 48125.5195
# Epoch 28/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4500213248.0000 - mean_absolute_error: 48412.7812 - val_loss: 4548042240.0000 - val_mean_absolute_error: 48573.9453
# Epoch 29/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4749609472.0000 - mean_absolute_error: 49616.6016 - val_loss: 4540434432.0000 - val_mean_absolute_error: 47944.2109
# Epoch 30/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4806690304.0000 - mean_absolute_error: 49583.4727 - val_loss: 4528186880.0000 - val_mean_absolute_error: 48114.5742
# Epoch 31/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 926us/step - loss: 4528783360.0000 - mean_absolute_error: 48664.9258 - val_loss: 4521608704.0000 - val_mean_absolute_error: 47938.7617
# Epoch 32/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1000us/step - loss: 4766112256.0000 - mean_absolute_error: 49280.8242 - val_loss: 4512166912.0000 - val_mean_absolute_error: 47853.6680
# Epoch 33/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4603738112.0000 - mean_absolute_error: 48911.2031 - val_loss: 4507726848.0000 - val_mean_absolute_error: 48122.0469
# Epoch 34/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 4681715200.0000 - mean_absolute_error: 49260.4453 - val_loss: 4497505280.0000 - val_mean_absolute_error: 48039.8398
# Epoch 35/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 4642714624.0000 - mean_absolute_error: 49191.4883 - val_loss: 4489519616.0000 - val_mean_absolute_error: 47799.0703
# Epoch 36/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 4517287424.0000 - mean_absolute_error: 48277.7148 - val_loss: 4482412032.0000 - val_mean_absolute_error: 47795.3320
# Epoch 37/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 4582369280.0000 - mean_absolute_error: 48733.8906 - val_loss: 4476393984.0000 - val_mean_absolute_error: 47595.5117
# Epoch 38/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4690731520.0000 - mean_absolute_error: 49156.7031 - val_loss: 4474448384.0000 - val_mean_absolute_error: 47441.3398
# Epoch 39/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4615713792.0000 - mean_absolute_error: 48449.5234 - val_loss: 4469171200.0000 - val_mean_absolute_error: 47286.9961
# Epoch 40/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 915us/step - loss: 4597657600.0000 - mean_absolute_error: 48033.0859 - val_loss: 4458357248.0000 - val_mean_absolute_error: 47645.7578
# Epoch 41/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 4705396736.0000 - mean_absolute_error: 48920.3086 - val_loss: 4450812928.0000 - val_mean_absolute_error: 47323.0586
# Epoch 42/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4619191808.0000 - mean_absolute_error: 48898.7148 - val_loss: 4442553856.0000 - val_mean_absolute_error: 47297.0000
# Epoch 43/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 942us/step - loss: 4547536384.0000 - mean_absolute_error: 48243.2852 - val_loss: 4436736000.0000 - val_mean_absolute_error: 47453.8789
# Epoch 44/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 4684725760.0000 - mean_absolute_error: 48850.6641 - val_loss: 4433495040.0000 - val_mean_absolute_error: 47147.1523
# Epoch 45/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 4390778368.0000 - mean_absolute_error: 47499.0625 - val_loss: 4425128960.0000 - val_mean_absolute_error: 47419.3086
# Epoch 46/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - loss: 4445460480.0000 - mean_absolute_error: 47950.5273 - val_loss: 4421871616.0000 - val_mean_absolute_error: 47517.4727
# Epoch 47/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 4467537920.0000 - mean_absolute_error: 48053.6758 - val_loss: 4412114432.0000 - val_mean_absolute_error: 47257.1641
# Epoch 48/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4750678528.0000 - mean_absolute_error: 48890.6914 - val_loss: 4405388800.0000 - val_mean_absolute_error: 47073.3398
# Epoch 49/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 4610880000.0000 - mean_absolute_error: 48489.5117 - val_loss: 4403351040.0000 - val_mean_absolute_error: 46957.3906
# Epoch 50/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4662907392.0000 - mean_absolute_error: 48354.5391 - val_loss: 4393670144.0000 - val_mean_absolute_error: 47083.1328

# %%
# Evaluate the model
loss, mae = model.evaluate(X_test, y_test)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {loss}")
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 4528955392.0000 - mean_absolute_error: 47264.2617
# Mean Absolute Error: 47083.1328125
# Mean Squared Error: 4393670144.0

# %%
# Make predictions on the testing data
y_pred = model.predict(X_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
import matplotlib.pyplot as plt

# Plotting a scatter plot to compare actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()

# %%
import numpy as np

comparison_array = np.column_stack((y_test, y_pred))
print("real value | predicted value")
print(comparison_array[:10])
# Out:
# real value | predicted value
# [[136900.       203649.4375  ]
#  [241300.       289372.8125  ]
#  [200700.       159846.453125]
#  [ 72500.        95701.96875 ]
#  [460000.       295437.15625 ]
#  [120000.       206052.171875]
#  [247000.       267509.8125  ]
#  [336900.       326301.5625  ]
#  [339700.       297866.8125  ]
#  [265600.       250946.21875 ]]

# %%
from tensorflow.keras.models import save_model
save_model(model, 'prediction_model.keras')
